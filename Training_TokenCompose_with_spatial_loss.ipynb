# %%
# !wget -O requirements.txt https://raw.githubusercontent.com/Raphael-Bernas/Training_TokenCompose/e23d9e5642bccacc7b72285f8f594388133c1bf8/requirements.txt
# !wget -O train.sh https://raw.githubusercontent.com/Raphael-Bernas/Training_TokenCompose/e23d9e5642bccacc7b72285f8f594388133c1bf8/train.sh
# !wget -O train_without_pixel.sh https://raw.githubusercontent.com/Raphael-Bernas/Training_TokenCompose/66b2217ed047bd2e5c7106ecc76b36fe9e96fc75/train_without_pixel.sh
# !wget -O train_without_token.sh https://raw.githubusercontent.com/Raphael-Bernas/Training_TokenCompose/66b2217ed047bd2e5c7106ecc76b36fe9e96fc75/train_without_token.sh
# Out:
# --2025-01-12 15:56:17--  https://raw.githubusercontent.com/Raphael-Bernas/Training_TokenCompose/e23d9e5642bccacc7b72285f8f594388133c1bf8/requirements.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 127 [text/plain]
# Saving to: ‘requirements.txt’
#
# requirements.txt    100%[===================>]     127  --.-KB/s    in 0s
#
# 2025-01-12 15:56:17 (12.0 MB/s) - ‘requirements.txt’ saved [127/127]
#
# --2025-01-12 15:56:17--  https://raw.githubusercontent.com/Raphael-Bernas/Training_TokenCompose/e23d9e5642bccacc7b72285f8f594388133c1bf8/train.sh
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# ...

# %%
# !python3 --version
# Out:
# Python 3.10.12

# %%
# !pip list
# Out:
# Package                            Version
# ---------------------------------- ------------------
# absl-py                            1.4.0
# accelerate                         1.2.1
# aiohappyeyeballs                   2.4.4
# aiohttp                            3.11.11
# aiosignal                          1.3.2
# alabaster                          1.0.0
# albucore                           0.0.19
# albumentations                     1.4.20
# altair                             5.5.0
# annotated-types                    0.7.0
# anyio                              3.7.1
# argon2-cffi                        23.1.0
# argon2-cffi-bindings               21.2.0
# array_record                       0.6.0
# arviz                              0.20.0
# astropy                            6.1.7
# astropy-iers-data                  0.2025.1.6.0.33.42
# astunparse                         1.6.3
# async-timeout                      4.0.3
# atpublic                           4.1.0
# ...

# %%
# !pip install torchvision==0.14.1 torchaudio==0.13.1
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.2/24.2 MB 85.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 103.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 887.5/887.5 MB 1.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 317.1/317.1 MB 3.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.0/21.0 MB 86.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 849.3/849.3 kB 45.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 557.1/557.1 MB 1.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: torch
#     Found existing installation: torch 2.5.1+cu121
#     Uninstalling torch-2.5.1+cu121:
#       Successfully uninstalled torch-2.5.1+cu121
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.20.1+cu121
#     Uninstalling torchvision-0.20.1+cu121:
#       Successfully uninstalled torchvision-0.20.1+cu121
#   Attempting uninstall: torchaudio
# ...

# %%
# !pip install --upgrade torch torchvision
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 906.4/906.4 MB 1.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 48.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 83.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 52.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 11.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 40.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 18.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 4.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.7/188.7 MB 12.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 82.1 MB/s eta 0:00:00
# ...

# %%
# !pip install -r requirements.txt
# Out:
# ...
#   Cloning https://github.com/openai/CLIP.git to /tmp/pip-req-build-5mssuyma
#   Running command git clone --filter=blob:none --quiet https://github.com/openai/CLIP.git /tmp/pip-req-build-5mssuyma
#   Resolved https://github.com/openai/CLIP.git to commit dcba3cb2e2827b402d2701e7e1c7d9fed8a20ef1
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 480.6/480.6 kB 11.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 4.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 10.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 179.3/179.3 kB 15.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 11.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 16.8 MB/s eta 0:00:00
# ...
#   Created wheel for clip: filename=clip-1.0-py3-none-any.whl size=1369489 sha256=23425c2c57999daaaeddf95ce4d6d2c96da7dbe85c5e7ee122a0a72257bcf40d
# ...

# %%
from google.colab import userdata
import os
os.environ['WANDB_API_KEY'] = userdata.get('WANDB_API_KEY')
# !wandb login
# Out:
# wandb: Currently logged in as: bernasraphael (bernasraphael-ensta-paris). Use `wandb login --relogin` to force relogin

# %%
# !git clone https://github.com/mlpc-ucsd/TokenCompose.git
# Out:
# Cloning into 'TokenCompose'...
# remote: Enumerating objects: 589, done.
# remote: Counting objects: 100% (46/46), done.
# remote: Compressing objects: 100% (13/13), done.
# remote: Total 589 (delta 38), reused 33 (delta 33), pack-reused 543 (from 1)
# Receiving objects: 100% (589/589), 213.70 MiB | 67.98 MiB/s, done.
# Resolving deltas: 100% (114/114), done.

# %%
# !rm TokenCompose/train/train.sh
# !mv train.sh TokenCompose/train/

# !mv train_without_pixel.sh TokenCompose/train/
# !mv train_without_token.sh TokenCompose/train/

# %%
# !pip install huggingface_hub

# %%
import os
os.chdir('TokenCompose/')
# !ls
# Out:
# LICENSE  multigen  notebooks  preprocess_data  README.md  requirements.txt  teaser.jpg	train

# %%
import os
os.chdir('train/data/')
# !bash coco_data_setup.sh
# Out:
# Le flux de sortie a été tronqué et ne contient que les 5000 dernières lignes.
#  extracting: train2017/000000569592.jpg
#  extracting: train2017/000000229396.jpg
#  extracting: train2017/000000488990.jpg
#  extracting: train2017/000000348684.jpg
#  extracting: train2017/000000234031.jpg
#  extracting: train2017/000000563584.jpg
#  extracting: train2017/000000276069.jpg
#  extracting: train2017/000000401194.jpg
#  extracting: train2017/000000502089.jpg
#  extracting: train2017/000000192183.jpg
#  extracting: train2017/000000425127.jpg
#  extracting: train2017/000000126766.jpg
#  extracting: train2017/000000324161.jpg
#  extracting: train2017/000000452746.jpg
#  extracting: train2017/000000423782.jpg
#  extracting: train2017/000000546343.jpg
#  extracting: train2017/000000249290.jpg
#  extracting: train2017/000000025529.jpg
#  extracting: train2017/000000316928.jpg
#  extracting: train2017/000000337866.jpg
#  extracting: train2017/000000547768.jpg
# ...

# %%
# !pip install gdown
# !gdown --id 16uoQpfZ0O-NW92HuaCaFU8K4cGHHbv4R
# !tar -xvf coco_gsam_seg.tar
# !rm coco_gsam_seg.tar
# Out:
# Le flux de sortie a été tronqué et ne contient que les 5000 dernières lignes.
# coco_gsam_seg/000000152742/mask_000000152742_cat.png
# coco_gsam_seg/000000420085/
# coco_gsam_seg/000000420085/src.jpg
# coco_gsam_seg/000000420085/mask_000000420085_wheel_barrow.png
# coco_gsam_seg/000000420085/mask_000000420085_sacks.png
# coco_gsam_seg/000000420085/mask_000000420085_donkey.png
# coco_gsam_seg/000000364720/
# coco_gsam_seg/000000364720/src.jpg
# coco_gsam_seg/000000364720/mask_000000364720_man.png
# coco_gsam_seg/000000364720/mask_000000364720_doughnuts.png
# coco_gsam_seg/000000057639/
# coco_gsam_seg/000000057639/src.jpg
# coco_gsam_seg/000000057639/mask_000000057639_man.png
# coco_gsam_seg/000000057639/mask_000000057639_knife.png
# coco_gsam_seg/000000057639/mask_000000057639_birthday_cake.png
# coco_gsam_seg/000000460143/
# coco_gsam_seg/000000460143/src.jpg
# coco_gsam_seg/000000460143/mask_000000460143_Madrid_city_tours.png
# coco_gsam_seg/000000460143/mask_000000460143_bus.png
# ...

# %%
import os
os.chdir('../')
# !pwd # /content/TokenCompose/train
# Out:
# /content/TokenCompose/train

# %%
# !nvidia-smi --list-gpus # If GPU = 0 please modify the train.sh code
# It is highly recommanded to reduce the num_workers & max_steps in train.sh
# Out:
# GPU 0: NVIDIA A100-SXM4-40GB (UUID: GPU-af8d1e53-002a-68f2-4d97-8da700cba2b6)

# %%
import os
os.chdir('src/')
# !wget -O loss_utils_spatial.py https://raw.githubusercontent.com/Raphael-Bernas/Training_TokenCompose/b1db637536f9e31bcf898dd20819ca48f942b359/loss_utils_spatial.py
# !wget -O train_token_compose_spatial.py https://raw.githubusercontent.com/Raphael-Bernas/Training_TokenCompose/b1db637536f9e31bcf898dd20819ca48f942b359/train_token_compose_spatial.py


os.chdir('../')
# !wget -O train_spatial.sh https://raw.githubusercontent.com/Raphael-Bernas/Training_TokenCompose/b1db637536f9e31bcf898dd20819ca48f942b359/train_spatial.sh

# %%
# !bash train_spatial.sh
import shutil
# shutil.make_archive("chekpoints", 'zip', "results/")
from google.colab import files
# files.download("chekpoints.zip")
# Out:
# Streaming output truncated to the last 5000 lines.
# wandb: WARNING Tried to log to step 360 that is less than the current step 1440. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 361 that is less than the current step 1444. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 362 that is less than the current step 1448. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# Steps:  18% 363/2050 [09:10<42:20,  1.51s/it, lr=5e-6, step_loss=0.04] ['A yellow banana and red apple sit', 'a wooden table.']
# Steps:  18% 363/2050 [09:11<42:20,  1.51s/it, lr=5e-6, step_loss=0.33]   ['A woman smiles in her dress while leaning', 'a hat wearing cow.']
# ...

# %%
import torch
from diffusers import StableDiffusionPipeline, UNet2DConditionModel
from PIL import Image
import numpy as np

# Function to load the UNet model from a checkpoint
def load_unet_from_checkpoint(checkpoint_dir, device):
    unet = UNet2DConditionModel.from_pretrained(checkpoint_dir, subfolder="unet")
    unet.to(device)
    return unet

# Function to generate an image from text using the replaced UNet
def generate_image(prompt, checkpoint_dir, device="cuda"):
    # Download Stable Diffusion 1.4 pipeline
    pipeline = StableDiffusionPipeline.from_pretrained("CompVis/stable-diffusion-v1-4")
    pipeline.to(device)

    # Load the custom UNet model from the checkpoint
    custom_unet = load_unet_from_checkpoint(checkpoint_dir, device)

    # Replace the UNet in the pipeline with the custom UNet
    pipeline.unet = custom_unet

    # Generate the image
    with torch.no_grad():
        image = pipeline(prompt, guidance_scale=7.5).images[0]

    return image

checkpoint_dir = "results/TokenCompose/checkpoint-2000"
prompt = "A photo of a train passing through a tropical forest where several penguins are playing with falling stars."
generated_image = generate_image(prompt, checkpoint_dir)
generated_image.save("generated_image.png")
display(generated_image)
# Out:
# model_index.json:   0%|          | 0.00/541 [00:00<?, ?B/s]
# Fetching 16 files:   0%|          | 0/16 [00:00<?, ?it/s]
# (…)ature_extractor/preprocessor_config.json:   0%|          | 0.00/342 [00:00<?, ?B/s]
# safety_checker/config.json:   0%|          | 0.00/4.56k [00:00<?, ?B/s]
# (…)kpoints/scheduler_config-checkpoint.json:   0%|          | 0.00/209 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.22G [00:00<?, ?B/s]
# ...
#   0%|          | 0/50 [00:00<?, ?it/s]
# <PIL.Image.Image image mode=RGB size=512x512>

# %%
import os
os.chdir('../multigen/')
# !pwd # /content/TokenCompose/multigen
# !wget -O gen_image_dist_easy.py https://raw.githubusercontent.com/Raphael-Bernas/Training_TokenCompose/3523aec2295c6a77ee5c0cbc887b58b9c51ab50a/gen_image_dist_easy.py
# !wget -O gen_json_dist_easy.py https://raw.githubusercontent.com/Raphael-Bernas/Training_TokenCompose/069b7c6768ea8fd24454fd48b0bbe5d6e49ff977/gen_json_dist_easy.py
# !wget -O gen_multigen_scores_easy.py https://raw.githubusercontent.com/Raphael-Bernas/Training_TokenCompose/069b7c6768ea8fd24454fd48b0bbe5d6e49ff977/gen_multigen_scores_easy.py
# !wget -O loading_checkpoint.py https://raw.githubusercontent.com/Raphael-Bernas/Training_TokenCompose/3523aec2295c6a77ee5c0cbc887b58b9c51ab50a/loading_checkpoint.py
# Out:
# /content/TokenCompose/multigen
# --2025-01-12 17:56:57--  https://raw.githubusercontent.com/Raphael-Bernas/Training_TokenCompose/3523aec2295c6a77ee5c0cbc887b58b9c51ab50a/gen_image_dist_easy.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2257 (2.2K) [text/plain]
# Saving to: ‘gen_image_dist_easy.py’
#
# gen_image_dist_easy 100%[===================>]   2.20K  --.-KB/s    in 0s
#
# 2025-01-12 17:56:57 (28.2 MB/s) - ‘gen_image_dist_easy.py’ saved [2257/2257]
#
# --2025-01-12 17:56:57--  https://raw.githubusercontent.com/Raphael-Bernas/Training_TokenCompose/069b7c6768ea8fd24454fd48b0bbe5d6e49ff977/gen_json_dist_easy.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.110.133, 185.199.109.133, ...
# ...

# %%
# Modify the path to checkpoint if needed
# !mkdir sample_imgs/
# !mkdir sample_imgs/TokenCompose_chekpoint-2000/
# !python gen_image_dist_easy.py --num_inference_steps 35 --num_images 10 --output_dir "sample_imgs/TokenCompose_chekpoint-2000" --resolution 512 --model_name "../train/results/TokenCompose/checkpoint-2000"
# Out:
# 2025-01-12 17:57:06.644602: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-01-12 17:57:06.665886: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-01-12 17:57:06.672190: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-01-12 17:57:07.880785: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Loading pipeline components...: 100% 7/7 [00:01<00:00,  6.94it/s]
# loaded model from checkpoint :../train/results/TokenCompose/checkpoint-2000
# Model loaded.
# Data prepared.
# Start generating images.
# ...

# %%
# !mkdir sample_jsons/
# !mkdir sample_jsons/TokenCompose_chekpoint-2000/
# !python gen_json_dist_easy.py --image_dir "sample_imgs/TokenCompose_chekpoint-2000/" --output_json_path sample_jsons/TokenCompose_chekpoint-2000/ --num_images 10
# Out:
# 2025-01-12 17:58:18.205798: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-01-12 17:58:18.226962: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-01-12 17:58:18.233354: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-01-12 17:58:19.523664: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# preprocessor_config.json: 100% 427/427 [00:00<00:00, 2.69MB/s]
# tokenizer_config.json: 100% 1.10k/1.10k [00:00<00:00, 7.97MB/s]
# vocab.json: 100% 1.06M/1.06M [00:00<00:00, 16.7MB/s]
# ...

# %%
# !python gen_multigen_scores_easy.py --result_path "sample_jsons/TokenCompose_chekpoint-2000/" --name "TokenCompose_SD14_check2000" --num_images 10
# Out:
# Reading Data ...
# Processing ...
# Model                        MG_1           MG_2           MG_3          MG_4         MG_5          Num_Imgs    det_threshold
# ---------------------------  -------------  -------------  ------------  -----------  ----------  ----------  ---------------
# TokenCompose_SD14_check2000  95.00(190.33)  90.00(181.38)  35.00(77.62)  5.00(15.00)  0.00(0.00)          20              0.1

# %% [markdown]
# # OptiGen :
#
# See https://github.com/Raphael-Bernas/OptiGen_benchmark.git

# %%
# !wget -O word_coco_obj_comp_5_1k.json https://raw.githubusercontent.com/Raphael-Bernas/OptiGen_benchmark/7141a9fa0607cad0665b4222e5692a1b1879149d/word_coco_obj_comp_5_1k.json
# Import necessary libraries
import os
import json
import torch
from tabulate import tabulate
import numpy as np

from tqdm import tqdm
from PIL import Image
from transformers import Owlv2Processor, Owlv2ForObjectDetection, GPT2Tokenizer, GPT2LMHeadModel
from diffusers import StableDiffusionPipeline

# Function to load the UNet model from a checkpoint
def load_unet_from_checkpoint(checkpoint_dir):
    unet = UNet2DConditionModel.from_pretrained(checkpoint_dir, subfolder="unet")
    return unet

def load_checkpoint(checkpoint_dir):
    # Download Stable Diffusion 1.4 pipeline
    pipeline = StableDiffusionPipeline.from_pretrained("CompVis/stable-diffusion-v1-4")

    # Load the custom UNet model from the checkpoint
    custom_unet = load_unet_from_checkpoint(checkpoint_dir)

    # Replace the UNet in the pipeline with the custom UNet
    pipeline.unet = custom_unet

    return pipeline

# Word dataset path
word_file_path = "word_coco_obj_comp_5_1k.json"

# Parameters :
# Number of prompts kept from the original dataset
N_prompt = 5

# Number of images generated per prompt
N_image = 10

# Threshold
threshold = 0.01
fthreshold = 0.1

# Output directory to stock the generated images
output_dir = "output_images"
output_json_path = "output_json"

# Device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

pipe = load_checkpoint("../train/results/TokenCompose/checkpoint-2000")
pipe.to(device)

name = "TokenCompose_chekpoint-2000"

## Model parameters for the image
num_inference_steps = 50
resolution = 512

# Create output directory if it doesn't exist
if not os.path.exists(output_dir):
    os.makedirs(output_dir)
if not os.path.exists(output_json_path):
    os.makedirs(output_json_path)

# Load word dataset
with open(word_file_path, "r") as f:
    text_data = json.load(f)

# Load GPT-2 model and tokenizer for the text probability
tokenizer = GPT2Tokenizer.from_pretrained("gpt2")
model = GPT2LMHeadModel.from_pretrained("gpt2")


def predict_word_probability(context, target_word):
    input_text = context + " " + target_word
    input_ids = tokenizer.encode(input_text, return_tensors="pt")
    context_ids = tokenizer.encode(context, return_tensors="pt")
    with torch.no_grad():
      outputs = model(input_ids)
      logits = outputs.logits

    target_token_id = tokenizer.encode(target_word, add_special_tokens=False)[0]
    target_logits = logits[0, -1, target_token_id]

    probabilities = torch.softmax(logits[0, -1], dim=-1)
    target_probability = probabilities[target_token_id].item()

    return target_probability


def make_doubly_stochastic(matrix):
    # Step 1: Row normalization
    row_sums = matrix.sum(axis=1, keepdims=True)
    matrix = matrix / row_sums  # Normalize rows

    # Step 2: Column normalization
    col_sums = matrix.sum(axis=0, keepdims=True)
    matrix = matrix / col_sums  # Normalize columns

    # Step 3 : Proximity value
    col_sums = np.array(col_sums)
    row_sums = np.array(row_sums)
    ones_col = np.ones_like(col_sums)
    ones_row = np.ones_like(row_sums)
    dist = np.sqrt(((ones_col - col_sums)**2).sum())
    dist += np.sqrt(((ones_row - row_sums)**2).sum())

    return matrix, dist


N_data = len(text_data)
P = torch.zeros((N_data, N_data))
print("Process data...")
for i in tqdm(range(N_data)):
    for j in range(N_data):
        P[i, j] = predict_word_probability("a picture of " + text_data[i], text_data[j])

# Make a doubly stochastic matrix
P, dist = make_doubly_stochastic(P)
dist_eval = dist
while dist > 1e-8 and np.abs(dist-dist_eval)>1e-9:
    dist_eval = dist
    P, dist = make_doubly_stochastic(P)

# Get the N_prompt smallest values and their indices
flattened_P = P.view(-1)
values, indices = torch.topk(flattened_P, N_prompt, largest=False)
row_indices = indices // N_data
col_indices = indices % N_data

# Get the couples of words the least probable
worst_couples = torch.stack((row_indices, col_indices), dim=1)

# Generate the images
print("Generating images...")
index = 0
for (i, j) in worst_couples:
    prompt = "a picture of " + text_data[i] + " and " + text_data[j]
    print(f"Generating images for prompt: {prompt}")
    for k in tqdm(range(N_image)):
        img_id = f"{index}_{k}"
        save_path = f"{output_dir}/{img_id}.png"
        image = pipe(prompt=prompt, height=resolution, width=resolution, num_inference_steps=num_inference_steps).images[0]
        image.save(save_path)
    index += 1

del pipe  # Delete the model
torch.cuda.empty_cache()  # Clear the GPU memory cache
def mg_by_index(index, couple_id, image_dir, word_data, num_ins, img_per_prompt,
                   threshold, model, processor, device):

    image_file_list = os.listdir(image_dir)
    image_file_postfix = ".png"

    if image_file_list[0].endswith(".jpg"):
        image_file_postfix = ".jpg"

    inses = [word_data[couple_id[i]] for i in range(num_ins)]
    texts = [["a photo of a {}".format(ins) for ins in inses]]

    results = {}
    for i in range(img_per_prompt):

        # read image here
        img_id = "{}_{}".format(index, i)
        impath = os.path.join(image_dir, f"{img_id}{image_file_postfix}")
        image = Image.open(impath)

        # detection here
        with torch.no_grad():
            inputs = processor(text=texts, images=image, return_tensors="pt").to(device)
            outputs = model(**inputs)
            target_sizes = torch.Tensor([image.size[::-1]]).to(device)
            outs = processor.post_process_object_detection(outputs=outputs, target_sizes=target_sizes)

        scores, labels = outs[0]["scores"], outs[0]["labels"]
        det_scores, det_labels = [], []
        for score, label in zip(scores, labels):
            # we save detections with score > 0.01
            # but will later use 0.1 for evaluation
            if score > threshold:
                det_scores.append(score.tolist())
                det_labels.append(inses[label.item()])

        results[img_id] = {
            "classes": det_labels,
            "scores": det_scores,
        }

    return results
# Load detection model
processor = Owlv2Processor.from_pretrained("google/owlv2-large-patch14-ensemble")
model_detection = Owlv2ForObjectDetection.from_pretrained("google/owlv2-large-patch14-ensemble")
model_detection.to(device)
model_detection.eval()

results_dict = {}

for index in tqdm(range(len(worst_couples))):
    results = mg_by_index(index=index,
                couple_id=worst_couples[index],
                image_dir=output_dir,
                word_data=text_data,
                num_ins=2,
                img_per_prompt=N_image,
                threshold=threshold,
                model=model_detection,
                processor=processor,
                device=device)
    for key, value in results.items():
          results_dict[key] = value

json_name = f"performance.json"
output_json_name = os.path.join(output_json_path, json_name)
with open(output_json_name, "w") as f:
    json.dump(results_dict, f, indent=4, separators=(",", ": "))


NUM_TO_PERCENT = 100

def get_multigen(list_couples, results, threshold, word_data, num_ins, img_per_prompt):
	mg_n = [0] * num_ins # num_ins
	mg_std = np.zeros((img_per_prompt, num_ins), dtype=np.float32) # num_ins, img_per_prompt

	for img_id, rr in results.items():
		uniq_id = int(img_id.split("_")[0])
		img_per_prompt_id = int(img_id.split("_")[1])
		obj_list = [word_data[list_couples[uniq_id][i]] for i in range(num_ins)]

		origin_detected = rr["classes"]
		origin_scores = rr["scores"]

		# filter by detection threshold
		assert len(origin_detected) == len(origin_scores), \
			"length of detected and scores should be same"

		detected = [origin_detected[i] for i in range(len(origin_scores)) if origin_scores[i] > threshold]
		generated_cnt = len(list(set(detected) & set(obj_list))) # intersection of detected and obj_list

		for k in range(generated_cnt):
			mg_n[k] += 1
			mg_std[img_per_prompt_id][k] += 1

	mg_std = ((NUM_TO_PERCENT * mg_std) / (len(results) / img_per_prompt))
	mg_std = np.std(mg_std, axis=0)

	# compute average
	mg_n = [NUM_TO_PERCENT * mg / len(results) for mg in mg_n]
	return mg_n, mg_std


# actually result path is result dir
results_files = output_json_name
results = {}


with open(results_files, "r") as f:
	results = json.load(f)

mg_n, mg_std = get_multigen(
    list_couples=worst_couples,
		results=results,
		threshold=fthreshold,
		word_data=text_data,
		num_ins=2,
		img_per_prompt=N_image,
)

mg_data = [name] + [f'{mg_n[i]:.2f}({mg_std[i]:.2f})' for i in range(2)] + [str(len(results)), str(fthreshold)]

headers = ['Model'] + [f'MG_{i+1}' for i in range(2)] + ['Num_Imgs', "det_threshold"]

print(
		tabulate(
			[mg_data],
			headers=headers,
			)
		)
# Out:
# --2025-01-12 17:58:50--  https://raw.githubusercontent.com/Raphael-Bernas/OptiGen_benchmark/7141a9fa0607cad0665b4222e5692a1b1879149d/word_coco_obj_comp_5_1k.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 861 [text/plain]
# Saving to: ‘word_coco_obj_comp_5_1k.json’
#
# word_coco_obj_comp_ 100%[===================>]     861  --.-KB/s    in 0s
#
# 2025-01-12 17:58:50 (55.5 MB/s) - ‘word_coco_obj_comp_5_1k.json’ saved [861/861]
# Loading pipeline components...:   0%|          | 0/7 [00:00<?, ?it/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# ...

# %%
import shutil
shutil.make_archive("output_images", 'zip', "output_images/")
from google.colab import files
files.download("output_images.zip")

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.chdir('../train')
# !pwd
# Out:
# /content/TokenCompose/train

# %%
import shutil

source_dir = 'results/TokenCompose/checkpoint-2000/'
destination_dir = '/content/drive/MyDrive/checkpoint-2000Spatial/'

shutil.copytree(source_dir, destination_dir)
# Out:
# '/content/drive/MyDrive/checkpoint-2000Spatial/'

# %%
import wandb
import numpy as np
import matplotlib.pyplot as plt

eta = 1e-5
# Verify login
api = wandb.Api()

project_name = "TokenCompose"
entity_name = "bernasraphael-ensta-paris"
run_id = "pk94k8pc"

run = api.run(f"{entity_name}/{project_name}/{run_id}")

# Get the history
history = run.history()
keys = history.columns

# List of logged losses and metrics
print("Available keys in the history:")
for key in keys:
    print(key)

spatial_layers = [
    "spatial/mid_8",
    "spatial/up_64",
    "spatial/up_32",
    "spatial/up_16"
]

spatial_loss_w_scale = []
pixel_loss_w_scale = []
token_loss_w_scale = []

for i in range(len(history[spatial_layers[1]])):
  spatial_loss_sum = sum(history[layer][i] for layer in spatial_layers)
  spatial_loss_w_scale.append(spatial_loss_sum * eta)
  pixel_loss_w_scale.append(history['train/pixel_loss_w_scale'][i])
  token_loss_w_scale.append(history['train/token_loss_w_scale'][i])

# Create the plot
plt.figure(figsize=(10, 6))

# Plot the three normalized losses
plt.plot(spatial_loss_w_scale, label="Spatial Loss (scaled by eta)", color='blue', linestyle='-', marker='o')
plt.plot(pixel_loss_w_scale, label="Pixel Loss (scaled)", color='green', linestyle='-', marker='x')
plt.plot(token_loss_w_scale, label="Token Loss (scaled)", color='red', linestyle='-', marker='s')

# Add labels and title
plt.xlabel("Steps")
plt.ylabel("Normalized Loss Value")
plt.title("Comparison of Normalized Losses")
plt.legend()

# Display the plot
plt.show()

window_size = 10

# Define a simple moving average function
def moving_average(data, window_size):
    return np.convolve(data, np.ones(window_size)/window_size, mode='valid')

# Smooth the results using the moving average function
spatial_loss_smoothed = moving_average(spatial_loss_w_scale, window_size)
pixel_loss_smoothed = moving_average(pixel_loss_w_scale, window_size)
token_loss_smoothed = moving_average(token_loss_w_scale, window_size)

# Create the plot
plt.figure(figsize=(10, 6))

# Plot the three smoothed losses
plt.plot(spatial_loss_smoothed, label="Smoothed Spatial Loss (scaled)", color='blue', linestyle='-', marker='o')
plt.plot(pixel_loss_smoothed, label="Smoothed Pixel Loss (scaled)", color='green', linestyle='-', marker='x')
plt.plot(token_loss_smoothed, label="Smoothed Token Loss (scaled)", color='red', linestyle='-', marker='s')

# Add labels and title
plt.xlabel("Steps")
plt.ylabel("Smoothed Loss Value")
plt.title("Comparison of Smoothed Losses")
plt.legend()

# Display the plot
plt.show()
# Out:
# True
# Available keys in the history:
# token/up_64
# step/step_cnt
# train/token_loss_w_scale
# spatial/up_32
# token/mid_8
# pixel/up_64
# _runtime
# _timestamp
# token/up_16
# train/total_loss
# spatial/mid_8
# spatial/up_16
# pixel/up_32
# token/up_32
# lr/learning_rate
# train/denoise_loss
# pixel/mid_8
# pixel/up_16
# train/pixel_loss_w_scale
# _step
# spatial/up_64
